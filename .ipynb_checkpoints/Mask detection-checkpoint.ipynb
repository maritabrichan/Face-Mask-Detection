# %% [markdown]
# ## Import libraries

# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\programdata\anaconda3\lib\site-packages (0.5.4)

# %%
import os
import cv2
import numpy as np
import random
import keras

from imutils import paths
import matplotlib.pyplot as plt
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout,BatchNormalization,MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report

# %% [markdown]
# ## sample inage

# %% [markdown]
# ### With Mask

# %%
images_withMask = os.listdir("./New Masks Dataset/Train/Mask")
sample_img_withMask = random.choice(images_withMask)
image = load_img("./New Masks Dataset/Train/Mask/"+sample_img_withMask)
plt.imshow(image)
# Out:
# 1247.jpg

# %% [markdown]
# ### Without Mask

# %%
images_withoutMask = os.listdir("./New Masks Dataset/Train/Non Mask")
sample_img_withoutMask = random.choice(images_withoutMask)
image = load_img("./New Masks Dataset/Train/Non Mask/"+sample_img_withoutMask)
plt.imshow(image)

# %% [markdown]
# ## Data Augmentation

# %%
img_width=224
img_height=224

# initialize the initial learning rate, number of epochs to train for, and batch size
INIT_LR = 1e-4
EPOCHS = 50
BS = 32
train_data_dir="./New Masks Dataset/Train"
test_data_dir="./New Masks Dataset/Validation"

all_train_imagePaths = list(paths.list_images(train_data_dir))
all_test_imagePaths = list(paths.list_images(test_data_dir))
train_data = []
train_labels = []
test_data = []
test_labels = []

# %%
# loop over the image paths
for imagePath in all_train_imagePaths:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]

	# load the input image (224x224) and preprocess it
	image = load_img(imagePath, target_size=(224, 224))
	image = img_to_array(image)
	image = preprocess_input(image)

	# update the data and labels lists, respectively
	train_data.append(image)
	train_labels.append(label)

# %%
# loop over the image paths
for imagePath in all_test_imagePaths:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]

	# load the input image (224x224) and preprocess it
	image = load_img(imagePath, target_size=(224, 224))

	image = img_to_array(image)
	image = preprocess_input(image)

	# update the data and labels lists, respectively
	test_data.append(image)
	test_labels.append(label)

# %%
def convert_data_labels(data,labels):
  # convert the data and labels to NumPy arrays
  data = np.array(data, dtype="float32")
  labels = np.array(labels)

  # perform one-hot encoding on the labels
  lb = LabelBinarizer()
  labels = lb.fit_transform(labels)
  labels = to_categorical(labels)
  return  data,labels

# %%
train_data,train_labels = convert_data_labels(train_data,train_labels)
test_data,test_labels = convert_data_labels(test_data,test_labels)

# %%
print("==================================")
print("Size of train dataset : ",train_data.shape[0])
print("==================================")
print("Size of test dataset : ",test_data.shape[0])
print("==================================")
# Out:
# ==================================
# Size of train dataset :  600
# ==================================
# Size of test dataset :  306
# ==================================

# %%
# train datagen
train_datagen = ImageDataGenerator(
                  rotation_range=20,
                  zoom_range=0.15,
                  width_shift_range=0.2,
                  height_shift_range=0.2,
                  shear_range=0.15,
                  horizontal_flip=True,
                  fill_mode="nearest")

train_generator = train_datagen.flow(train_data, train_labels, batch_size=BS)

# %% [markdown]
# # #  Model Building

# %% [markdown]
# ### Load MobileNetV2

# %%
# load the MobileNetV2 network, ensuring the head FC layer sets are left off
mobilenet = MobileNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 4s 0us/step
# 9420800/9406464 [==============================] - 4s 0us/step

# %%
# construct the head of the model that will be placed on top of the the base model
headModel = mobilenet.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# %%
# place the head FC model on top of the base model (this will become the actual model we will train)
model = Model(inputs=mobilenet.input, outputs=headModel)

# %%
# compile our model
print("[INFO] compiling model...")
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
print("Done !!")
# Out:
# [INFO] compiling model...
# Done !!

# %%
# loop over all layers in the base model and freeze them so they will *not* be updated during the first training process
for layer in mobilenet.layers:
	layer.trainable = False

# %%
# this code is to show how much time required to train the model using different algorithms
from datetime import datetime
def timer(start_time= None):
  if not start_time:
    start_time=datetime.now()
    return start_time
  elif start_time:
    thour,temp_sec=divmod((datetime.now()-start_time).total_seconds(),3600)
    tmin,tsec=divmod(temp_sec,60)
    print('\n Time taken: %i hours %i minutes and %s seconds. '% (thour,tmin,round(tsec,2)))

# %% [markdown]
# ### Callback Function

# %%
# checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
# # history=model.fit(train_data,train_target,epochs=100,callbacks=[checkpoint],validation_split=0.2)
# EarlyStopping
earlystop = EarlyStopping(monitor = 'val_loss',
                          min_delta = 0,
                          patience = 7,
                          verbose = 1,
                          restore_best_weights = True)

# ModelCheckPoint
checkPoint = keras.callbacks.ModelCheckpoint(filepath="/content/sample_data/fmd_model.h5",
                             monitor='val_loss',
                             mode='auto',
                             save_best_only=True,
                             verbose=1)

# ReduceLROnPlateau
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# TBoard = tf.keras.callbacks.TensorBoard(log_dir='./logs')

# %%
callbacks = [earlystop , checkPoint, learning_rate_reduction]

# %% [markdown]
# ## Model Fitting

# %%
start_time=timer(None)
classifier = model.fit(
    train_datagen.flow(train_data, train_labels, batch_size=BS), 
    epochs=EPOCHS,
    validation_data=(test_data,test_labels),
    validation_steps=len(test_data)//BS,
    steps_per_epoch=len(train_data)//BS,
    callbacks=callbacks
)
timer(start_time)
# Out:
# Epoch 1/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.8003
# Epoch 1: val_loss improved from inf to 0.43756, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 181s 8s/step - loss: 0.4980 - accuracy: 0.8003 - val_loss: 0.4376 - val_accuracy: 0.7712 - lr: 1.0000e-04
# Epoch 2/50
# 18/18 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9771
# Epoch 2: val_loss improved from 0.43756 to 0.38749, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 119s 7s/step - loss: 0.1336 - accuracy: 0.9771 - val_loss: 0.3875 - val_accuracy: 0.8072 - lr: 1.0000e-04
# Epoch 3/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9842
# Epoch 3: val_loss improved from 0.38749 to 0.29641, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 115s 6s/step - loss: 0.0589 - accuracy: 0.9842 - val_loss: 0.2964 - val_accuracy: 0.8627 - lr: 1.0000e-04
# Epoch 4/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9983
# Epoch 4: val_loss improved from 0.29641 to 0.25604, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 119s 7s/step - loss: 0.0289 - accuracy: 0.9983 - val_loss: 0.2560 - val_accuracy: 0.8954 - lr: 1.0000e-04
# Epoch 5/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9982
# Epoch 5: val_loss improved from 0.25604 to 0.16114, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 149s 8s/step - loss: 0.0201 - accuracy: 0.9982 - val_loss: 0.1611 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Epoch 6/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9982
# Epoch 6: val_loss improved from 0.16114 to 0.14005, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 136s 7s/step - loss: 0.0093 - accuracy: 0.9982 - val_loss: 0.1400 - val_accuracy: 0.9477 - lr: 1.0000e-04
# Epoch 7/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9982
# Epoch 7: val_loss did not improve from 0.14005
# 18/18 [==============================] - 131s 7s/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.1545 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Epoch 8/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 1.0000
# Epoch 8: val_loss did not improve from 0.14005
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 18/18 [==============================] - 141s 8s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9444 - lr: 1.0000e-04
# Epoch 9/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9965
# Epoch 9: val_loss improved from 0.14005 to 0.11718, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 135s 7s/step - loss: 0.0132 - accuracy: 0.9965 - val_loss: 0.1172 - val_accuracy: 0.9706 - lr: 5.0000e-05
# Epoch 10/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 10: val_loss improved from 0.11718 to 0.08291, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 128s 7s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9837 - lr: 5.0000e-05
# Epoch 11/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.08291 to 0.08157, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 125s 7s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9804 - lr: 5.0000e-05
# Epoch 12/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.08157 to 0.07802, saving model to /content/sample_data\fmd_model.h5
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 18/18 [==============================] - 124s 7s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9804 - lr: 5.0000e-05
# Epoch 13/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.07802 to 0.06858, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 125s 7s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9869 - lr: 2.5000e-05
# Epoch 14/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.06858 to 0.06302, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 125s 7s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9902 - lr: 2.5000e-05
# Epoch 15/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.06302 to 0.05979, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 120s 7s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9902 - lr: 2.5000e-05
# Epoch 16/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9982
# Epoch 16: val_loss improved from 0.05979 to 0.05877, saving model to /content/sample_data\fmd_model.h5
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 18/18 [==============================] - 117s 6s/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0588 - val_accuracy: 0.9902 - lr: 2.5000e-05
# Epoch 17/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.05877 to 0.05643, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 115s 6s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9902 - lr: 1.2500e-05
# Epoch 18/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.05643 to 0.05378, saving model to /content/sample_data\fmd_model.h5
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1e-05.
# 18/18 [==============================] - 117s 6s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9902 - lr: 1.2500e-05
# Epoch 19/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.05378 to 0.05161, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 118s 6s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 20/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.05161 to 0.04947, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 133s 7s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 21/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.04947 to 0.04756, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 129s 7s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 22/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.04756 to 0.04563, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 119s 7s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 23/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9965
# Epoch 23: val_loss improved from 0.04563 to 0.04303, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 116s 6s/step - loss: 0.0079 - accuracy: 0.9965 - val_loss: 0.0430 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 24/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.04303 to 0.04183, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 119s 7s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 25/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.04183 to 0.04076, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 124s 7s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 26/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.04076 to 0.03979, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 123s 7s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 27/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.03979 to 0.03886, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 123s 7s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 28/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.03886 to 0.03800, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 136s 7s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 29/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.03800 to 0.03710, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 130s 7s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 30/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.03710 to 0.03649, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 134s 7s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 31/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9982
# Epoch 31: val_loss did not improve from 0.03649
# 18/18 [==============================] - 117s 6s/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0371 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 32/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 32: val_loss improved from 0.03649 to 0.03647, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 120s 6s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 33/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9965
# Epoch 33: val_loss improved from 0.03647 to 0.03440, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 133s 7s/step - loss: 0.0079 - accuracy: 0.9965 - val_loss: 0.0344 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 34/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.03440 to 0.03305, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 127s 7s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 35/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 35: val_loss improved from 0.03305 to 0.03269, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 119s 6s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 36/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.03269 to 0.03245, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 127s 7s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 37/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.03245 to 0.03099, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 122s 7s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 38/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 38: val_loss improved from 0.03099 to 0.03058, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 142s 8s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 39/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 39: val_loss improved from 0.03058 to 0.03040, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 131s 7s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 40/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.03040 to 0.03014, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 120s 7s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 41/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 41: val_loss improved from 0.03014 to 0.02990, saving model to /content/sample_data\fmd_model.h5
# 18/18 [==============================] - 122s 7s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 42/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.02990
# 18/18 [==============================] - 121s 6s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 43/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.02990
# 18/18 [==============================] - 117s 6s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 44/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.02990
# 18/18 [==============================] - 118s 6s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9902 - lr: 1.0000e-05
# Epoch 45/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.02990
# 18/18 [==============================] - 118s 6s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 46/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9982
# Epoch 46: val_loss did not improve from 0.02990
# 18/18 [==============================] - 117s 6s/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0329 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 47/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9965
# Epoch 47: val_loss did not improve from 0.02990
# 18/18 [==============================] - 114s 6s/step - loss: 0.0061 - accuracy: 0.9965 - val_loss: 0.0351 - val_accuracy: 0.9869 - lr: 1.0000e-05
# Epoch 48/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 41.
#
# Epoch 48: val_loss did not improve from 0.02990
# 18/18 [==============================] - 117s 6s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9869 - lr: 1.0000e-05
# Epoch 48: early stopping
#
#  Time taken: 1 hours 47 minutes and 55.05 seconds.

# %% [markdown]
# ## Training Loss and Accuracy Visualization

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
N = 10 # epochs number
plt.figure()
plt.plot( classifier.history["loss"], label="train_loss")
plt.plot( classifier.history["val_loss"], label="val_loss")
plt.plot( classifier.history["accuracy"], label="train_acc")
plt.plot( classifier.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("CNN_Model")

# %% [markdown]
# ### Find Prediction

# %%
# make predictions on the testing set
print("[INFO] evaluating network...")
predIdxs = model.predict(test_data, batch_size=BS)
# Out:
# [INFO] evaluating network...

# %%
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# %% [markdown]
# ### Find Accuracy

# %%
# check accuracy
val_loss,val_acc = model.evaluate(test_data,test_labels)
print("=======================================================")
print("Accuracy is : ",val_acc)
print("=======================================================")
print("Loss is : ",val_loss)
print("=======================================================")
# Out:
# 10/10 [==============================] - 24s 800ms/step - loss: 0.0299 - accuracy: 0.9902
# =======================================================
# Accuracy is :  0.9901960492134094
# =======================================================
# Loss is :  0.029900360852479935
# =======================================================

# %% [markdown]
# ### Classification Report

# %%
# show a nicely formatted classification report
print(classification_report(test_labels.argmax(axis=1), predIdxs))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       153
#            1       0.99      0.99      0.99       153
#
#     accuracy                           0.99       306
#    macro avg       0.99      0.99      0.99       306
# weighted avg       0.99      0.99      0.99       306
